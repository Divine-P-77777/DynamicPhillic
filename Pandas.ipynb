# %% [markdown]
# <a href="https://colab.research.google.com/github/Divine-P-77777/DynamicPhillic/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
dyna = {
    "name":['Deepak','Nitesh','Nikhil','Aryan'],
    "marks" :['97','98','78','80'],
    "city" :['Guwahati','Hydrabed','Shillong','Darjeling']

}

# %%
df = pd.DataFrame(dyna)

# %%
df
# Out:
#      name marks       city
# 0  Deepak    97   Guwahati
# 1  Nitesh    98   Hydrabed
# 2  Nikhil    78   Shillong
# 3   Aryan    80  Darjeling

# %%
df.to_csv('dyna.csv')

# %%
df.to_csv('dyna_index_false.csv',index=False)
# DataFrame without index

# %%
df.head(2)
#Show first 2 rows
# Out:
#      name marks      city
# 0  Deepak    97  Guwahati
# 1  Nitesh    98  Hydrabed

# %%
df.tail(2)
#Show last 2 rows
# Out:
#      name marks       city
# 2  Nikhil    78   Shillong
# 3   Aryan    80  Darjeling

# %%
df.describe()
#describe the numerical caluction like statics an all
# Out:
#           name marks      city
# count        4     4         4
# unique       4     4         4
# top     Deepak    97  Guwahati
# freq         1     1         1

# %%
Dyan = pd.read_csv('dyna.csv')

# %%
Dyan
# Out:
#    Unnamed: 0    name  marks       city
# 0           0  Deepak     97   Guwahati
# 1           1  Nitesh     98   Hydrabed
# 2           2  Nikhil     78   Shillong
# 3           3   Aryan     80  Darjeling

# %%
Dyan.describe()
# Out:
#        Unnamed: 0      marks
# count    4.000000   4.000000
# mean     1.500000  88.250000
# std      1.290994  10.719919
# min      0.000000  78.000000
# 25%      0.750000  79.500000
# 50%      1.500000  88.500000
# 75%      2.250000  97.250000
# max      3.000000  98.000000

# %%
Dyan['city'] [1] = 'Guwahati'
# Out:
# <ipython-input-22-f1ab09ce23fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dyan['city'] [1] = 'Guwahati'

# %%
Dyan
# Out:
#    Unnamed: 0    name  marks       city
# 0           0  Deepak     97   Guwahati
# 1           1  Nitesh     98   Guwahati
# 2           2  Nikhil     78   Shillong
# 3           3   Aryan     80  Darjeling

# %%
Dyan.index = ['a','b','c','d']

# %%
Dyan
# Out:
#    Unnamed: 0    name  marks       city
# a           0  Deepak     97   Guwahati
# b           1  Nitesh     98   Guwahati
# c           2  Nikhil     78   Shillong
# d           3   Aryan     80  Darjeling
